# %%
{
    "iou_threshold": 0.45,
    "detection_threshold": 0.7,
    "output_activation": "none",
    "label_offset": 1,
    "max_boxes": 50,
    "anchors": [
        [257, 247, 204, 196, 412, 390],
        [357, 338, 230, 221, 318, 304],
        [143, 137, 176, 167, 284, 274]
    ],
    "labels": [
        "tangerines_canker",
        "tangerines_normal"
    ]
}

# %%
Calculated Anchor Boxes (width, height):
[[    0.34434     0.33015]
 [    0.43173     0.41563]
 [    0.29384     0.28205]
 [    0.62447     0.59113]
 [    0.23515     0.22402]
 [    0.38767      0.3716]
 [    0.47882     0.46508]
 [    0.54266     0.52476]
 [    0.54753     0.45088]]

# %%
# !pip install ultralytics
# !pip install numpy
# !pip install torch
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.3/887.3 kB 13.6 MB/s eta 0:00:00
# ...

# %%
import torch
import numpy as np

# 모델 불러오기 (YOLOv8 예제)
from ultralytics import YOLO

model = YOLO('best.pt')
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from google.colab.patches import cv2_imshow
import cv2
import torch
from ultralytics import YOLO
import numpy as np

# %%
from ultralytics import YOLO

# 모델 불러오기
model = YOLO("best.pt")

# 클래스 이름 추출
class_labels = model.names

# 앵커 추출 (YOLOv5나 YOLOv8 등에서는 앵커 정보가 없을 수 있습니다.)
anchors = model.model.anchors if hasattr(model.model, 'anchors') else None

print(f"Labels: {class_labels}")
print(f"Anchors: {anchors}")
# Out:
# Labels: {0: 'tangerines_canker', 1: 'tangerines_normal'}
# Anchors: None
